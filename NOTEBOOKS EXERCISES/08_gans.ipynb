# %% [markdown]
# # 8. Redes Generativas Antagónicas (GANs) 🎨
#
# En este notebook aprenderás los fundamentos de las GANs, cómo entrenar un generador y un discriminador, y verás ejemplos prácticos con TensorFlow/Keras.
#
# ✨ **Highlights:**
# - Implementación de una GAN con BatchNormalization y label smoothing
# - Monitoreo de convergencia mediante curvas de pérdida
# - Diagnóstico visual de mode collapse
# - Evolución de imágenes generadas a lo largo del entrenamiento

# %% [markdown]
# ## Objetivo
# - Comprender la teoría y arquitectura de las GANs.
# - Implementar y entrenar una GAN para generación de dígitos.
# - Analizar el impacto de los hiperparámetros y visualizar resultados.
# - Aplicar buenas prácticas para entrenamiento estable.

# %% [markdown]
# ## Prerequisitos
#
# > 📌 **Prerequisitos:** Haber completado los notebooks [04 (MLP)](./04_redes_neuronales_capa_densa.ipynb) y [05 (CNN)](./05_redes_convolucionales_cnn.ipynb).
#
# - Conceptos de redes neuronales, funciones de activación y entrenamiento con Keras.

# %% [markdown]
# ## 1. Introducción teórica
#
# Las GANs consisten en dos redes que compiten entre sí:
#
# - **Generador:** Crea datos falsos a partir de ruido aleatorio.
# - **Discriminador:** Intenta distinguir entre datos reales y generados.
#
# El entrenamiento es un «juego» donde ambas redes mejoran mutuamente.
#
# **Ventajas:** Capaces de generar datos hiperrealistas (imágenes, audio).
# **Desventajas:** Difíciles de entrenar (inestabilidad, mode collapse).

# %% [markdown]
# ## 2. Importación de librerías

# %%
import random
import numpy as np
import os
import logging

# === Reproducibilidad ===
SEED = 42
random.seed(SEED)
np.random.seed(SEED)

# Suprimir logs de XLA/oneDNN antes de importar TF
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
logging.getLogger('tensorflow').setLevel(logging.ERROR)

import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
tf.random.set_seed(SEED)

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# === Información del dispositivo ===
print(f'TensorFlow: {tf.__version__}')
gpus = tf.config.list_physical_devices('GPU')
print(f'GPUs disponibles: {len(gpus)}')
if gpus:
    for gpu in gpus:
        print(f'  ✅ {gpu.name}')
else:
    print('  ⚠️  Sin GPU — el entrenamiento será más lento')
print('─' * 50)
# Out:
# TensorFlow: 2.20.0
# GPUs disponibles: 0
#   ⚠️  Sin GPU — el entrenamiento será más lento
# ──────────────────────────────────────────────────

# %% [markdown]
# ## 3. Carga de datos y definición de la GAN
#
# Crearemos una GAN para generar dígitos similares a MNIST. El generador usa **BatchNormalization** para mejorar la estabilidad.

# %%
# Cargar MNIST
(X_train, _), (_, _) = keras.datasets.mnist.load_data()
X_train = X_train.astype('float32') / 255.0
X_train = X_train.reshape(-1, 28*28)

LATENT_DIM = 100

# Generador con BatchNormalization (buena práctica)
def build_generator(latent_dim=LATENT_DIM):
    model = keras.Sequential([
        keras.layers.Dense(128, input_dim=latent_dim),
        keras.layers.BatchNormalization(),
        keras.layers.LeakyReLU(0.2),
        keras.layers.Dense(256),
        keras.layers.BatchNormalization(),
        keras.layers.LeakyReLU(0.2),
        keras.layers.Dense(28*28, activation='sigmoid')
    ])
    return model

# Discriminador con LeakyReLU
def build_discriminator():
    model = keras.Sequential([
        keras.layers.Dense(256, input_dim=28*28),
        keras.layers.LeakyReLU(0.2),
        keras.layers.Dense(128),
        keras.layers.LeakyReLU(0.2),
        keras.layers.Dense(1, activation='sigmoid')
    ])
    return model

generator = build_generator()
discriminator = build_discriminator()
discriminator.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

discriminator.trainable = False

# Modelo GAN combinado
z = keras.Input(shape=(LATENT_DIM,))
img = generator(z)
valid = discriminator(img)
gan = keras.Model(z, valid)
gan.compile(optimizer='adam', loss='binary_crossentropy')

print('Generador:')
generator.summary()
print('\nDiscriminador:')
discriminator.summary()
# Out:
# Generador:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                │ (None, 128)            │        12,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_8 (LeakyReLU)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_9 (LeakyReLU)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 784)            │       201,488 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 248,976 (972.56 KB)
#  Trainable params: 248,208 (969.56 KB)
#  Non-trainable params: 768 (3.00 KB)
# Discriminador:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_15 (Dense)                │ (None, 256)            │       200,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_10 (LeakyReLU)      │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_11 (LeakyReLU)      │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 233,985 (914.00 KB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 233,985 (914.00 KB)

# %% [markdown]
# ## 4. Entrenamiento de la GAN
#
# Entrenamos alternando discriminador y generador. Usamos **label smoothing** (etiquetas reales = 0.9 en lugar de 1.0) para estabilizar.

# %%
import time

def sample_images(epoch, n=10):
    noise = np.random.normal(0, 1, (n, LATENT_DIM))
    gen_imgs = generator.predict(noise, verbose=0)
    gen_imgs = gen_imgs.reshape(n, 28, 28)
    plt.figure(figsize=(n, 2))
    for i in range(n):
        plt.subplot(1, n, i+1)
        plt.imshow(gen_imgs[i], cmap='gray')
        plt.axis('off')
    plt.suptitle(f'Época {epoch}')
    plt.tight_layout()
    plt.show()

def check_mode_collapse(gen_imgs, threshold=0.95):
    """Detecta mode collapse calculando la similitud media entre imágenes generadas."""
    gen_flat = gen_imgs.reshape(len(gen_imgs), -1)
    norms = np.linalg.norm(gen_flat, axis=1, keepdims=True)
    gen_norm = gen_flat / (norms + 1e-8)
    sim_matrix = gen_norm @ gen_norm.T
    np.fill_diagonal(sim_matrix, 0)
    avg_sim = sim_matrix.mean()
    if avg_sim > threshold:
        print(f'  ⚠️  Posible mode collapse detectado (similitud promedio: {avg_sim:.3f})')
    return avg_sim

def train_gan(epochs=500, batch_size=128, sample_interval=100):
    half_batch = batch_size // 2
    d_losses, g_losses, d_accs = [], [], []

    start_time = time.time()

    for epoch in range(epochs):
        # Entrenar discriminador
        idx = np.random.randint(0, X_train.shape[0], half_batch)
        real_imgs = X_train[idx]
        noise = np.random.normal(0, 1, (half_batch, LATENT_DIM))
        gen_imgs = generator.predict(noise, verbose=0)

        # Label smoothing: 0.9 en vez de 1.0 para reales
        d_loss_real = discriminator.train_on_batch(real_imgs, np.ones((half_batch, 1)) * 0.9)
        d_loss_fake = discriminator.train_on_batch(gen_imgs, np.zeros((half_batch, 1)))
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

        # Entrenar generador
        noise = np.random.normal(0, 1, (batch_size, LATENT_DIM))
        g_loss = gan.train_on_batch(noise, np.ones((batch_size, 1)))

        d_losses.append(d_loss[0])
        g_losses.append(g_loss)
        d_accs.append(d_loss[1])

        if epoch % sample_interval == 0:
            elapsed = time.time() - start_time
            print(f'Epoch {epoch:4d}/{epochs} | D loss: {d_loss[0]:.4f}, acc: {100*d_loss[1]:.1f}% '
                  f'| G loss: {g_loss:.4f} | ⏱ {elapsed:.1f}s')
            sample_images(epoch)
            # Diagnóstico de mode collapse
            noise_check = np.random.normal(0, 1, (50, LATENT_DIM))
            imgs_check = generator.predict(noise_check, verbose=0)
            check_mode_collapse(imgs_check)

    total_time = time.time() - start_time
    print(f'\n✅ Entrenamiento completo en {total_time:.1f}s ({total_time/60:.1f} min)')
    return d_losses, g_losses, d_accs

# Entrenar la GAN
d_losses, g_losses, d_accs = train_gan(epochs=500, batch_size=128, sample_interval=100)
# Out:
# Epoch    0/500 | D loss: 0.6563, acc: 0.0% | G loss: 0.5146 | ⏱ 1.8s
#   ⚠️  Posible mode collapse detectado (similitud promedio: 0.970)
# Epoch  100/500 | D loss: 2.1603, acc: 0.0% | G loss: 0.0199 | ⏱ 12.5s
#   ⚠️  Posible mode collapse detectado (similitud promedio: 0.965)
# Epoch  200/500 | D loss: 2.6623, acc: 0.0% | G loss: 0.0104 | ⏱ 23.8s
#   ⚠️  Posible mode collapse detectado (similitud promedio: 0.963)
# Epoch  300/500 | D loss: 3.0445, acc: 0.0% | G loss: 0.0071 | ⏱ 34.4s
#   ⚠️  Posible mode collapse detectado (similitud promedio: 0.964)
# Epoch  400/500 | D loss: 3.3313, acc: 0.0% | G loss: 0.0054 | ⏱ 44.7s
#   ⚠️  Posible mode collapse detectado (similitud promedio: 0.965)
#
# ✅ Entrenamiento completo en 55.2s (0.9 min)

# %% [markdown]
# ### Evolución de las pérdidas

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 4))

axes[0].plot(d_losses, label='Discriminador', alpha=0.7, color='steelblue')
axes[0].plot(g_losses, label='Generador', alpha=0.7, color='tomato')
axes[0].set_title('Evolución de las pérdidas')
axes[0].set_xlabel('Época')
axes[0].set_ylabel('Loss')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

axes[1].plot(d_accs, color='darkorange', alpha=0.7)
axes[1].axhline(0.5, color='gray', linestyle='--', label='Equilibrio (50%)')
axes[1].set_title('Exactitud del discriminador')
axes[1].set_xlabel('Época')
axes[1].set_ylabel('Accuracy')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.suptitle('Diagnóstico de entrenamiento GAN', fontweight='bold')
plt.tight_layout()
plt.show()

# Análisis de convergencia
print('📊 Diagnóstico de convergencia:')
print(f'  Pérdida D (últimas 50 épocas): {np.mean(d_losses[-50:]):.4f}')
print(f'  Pérdida G (últimas 50 épocas): {np.mean(g_losses[-50:]):.4f}')
print(f'  Acc. D   (últimas 50 épocas): {np.mean(d_accs[-50:])*100:.1f}%')
print('\n💡 Ideal: pérdidas D y G similares, accuracy D cercana al 50% (equilibrio Nash)')
# Out:
# 📊 Diagnóstico de convergencia:
#   Pérdida D (últimas 50 épocas): 3.4992
#   Pérdida G (últimas 50 épocas): 0.0046
#   Acc. D   (últimas 50 épocas): 0.0%
#
# 💡 Ideal: pérdidas D y G similares, accuracy D cercana al 50% (equilibrio Nash)

# %% [markdown]
# ## 5. Resultado final del generador

# %%
# Generar imágenes finales
sample_images('Final', n=10)

# %% [markdown]
# ### Recomendaciones prácticas para GANs
#
# | Aspecto | Recomendación |
# |---------|---------------|
# | **Estabilidad** | Usar BatchNormalization en el generador; LayerNorm en el discriminador |
# | **Label smoothing** | Etiquetas reales en [0.8, 1.0] — reduce confianza excesiva del discriminador |
# | **Activación** | LeakyReLU (α=0.2) en discriminador; ReLU o LeakyReLU en generador |
# | **Mode collapse** | Monitorear diversidad visual; prueba WGAN o espectral normalization |
# | **Learning rates** | D y G con LR distintos (e.g., D: 0.0001, G: 0.0002) |
# | **Equilibrio** | Si D loss → 0, el generador no aprende; reducir frecuencia de actualización D |
# | **Evaluación** | Inspección visual + FID score para calidad objetiva |
# | **GPU** | Esencial para más de 1000 epochs en imágenes ≥ 64×64 |
#
# > 💡 **Truco:** Si el discriminador gana demasiado rápido, entrena el generador 2× por cada actualización del discriminador (`n_critic = 2`).
#
# > ⚠️ **Mode collapse:** Si todas las imágenes generadas se ven iguales, la función `check_mode_collapse()` lo detectará. Señal para reiniciar o cambiar arquitectura.

# %% [markdown]
# ## 6. Discusión y Conclusiones
#
# **¿Qué aprendimos?**
#
# - Las GANs funcionan mediante un **juego de suma cero**: generador y discriminador mejoran mutuamente.
# - **BatchNormalization** en el generador y **label smoothing** en el discriminador son técnicas clave para estabilizar el entrenamiento.
# - La **accuracy del discriminador** cerca del 50% indica equilibrio — es la señal de convergencia saludable en una GAN.
# - El **mode collapse** es el problema más común: el generador colapsa en pocas variantes de salida. La función `check_mode_collapse()` permite detectarlo automáticamente.
# - Las curvas de pérdida de GANs son inherentemente ruidosas; lo importante es la tendencia y la calidad visual.
#
# **Para llevar:**
# - Monitorear siempre visualmente las imágenes generadas en intervalos regulares.
# - Para calidad real en producción, considerar **DCGAN** (convolucional), **StyleGAN** o **Diffusion Models** (estado del arte actual).
# - El FID (Fréchet Inception Distance) es la métrica estándar para evaluar GANs objetivamente.
#
# En el siguiente notebook veremos **Autoencoders**, otra familia de modelos generativos con espacio latente explícito.

# %% [markdown]
# ## 7. Ejercicios Propuestos
#
# 1. **Ejercicio 1:** Entrena con más epochs (2000-5000). ¿Mejora la calidad visual de los dígitos generados?
#
# 2. **Ejercicio 2:** Cambia el dataset a Fashion MNIST. ¿La GAN puede generar prendas de ropa reconocibles?
#
# 3. **Ejercicio 3:** Implementa una DCGAN (GAN con capas convolucionales) para mejor calidad de imagen.
#
# 4. **Ejercicio 4 (Avanzado):** Implementa una Conditional GAN (cGAN) que permita generar un dígito específico pasando la clase como condición.

# %% [markdown]
# #Ejercicio 1
#
# Qué se hizo:
# se aumentó el entrenamiento de la GAN a entre 2000 y 5000 epochs para comparar la evolución visual de los dígitos generados con respecto al entrenamiento corto del notebook .
#
# Qué se aprendió:
# se observa que más epochs suelen darle al generador más oportunidad de aprender la distribución de los dígitos, pero también puede aparecer inestabilidad o mode collapse si el entrenamiento se prolonga demasiado.
#
# Comparación antes/después:
#
# antes, con pocas epochs, las imágenes suelen verse más borrosas o incompletas; después, con más epochs, los dígitos tienden a verse más definidos, aunque no siempre mejora de forma lineal .

# %%
import numpy as np
import matplotlib.pyplot as plt

def generate_and_plot_images(generator, latent_dim=100, n_images=16):
    noise = np.random.normal(0, 1, (n_images, latent_dim))
    generated_imgs = generator.predict(noise, verbose=0)

    if generated_imgs.ndim == 2:
        side = int(np.sqrt(generated_imgs.shape[1]))
        generated_imgs = generated_imgs.reshape(-1, side, side)

    rows = int(np.sqrt(n_images))
    cols = int(np.ceil(n_images / rows))

    fig, axes = plt.subplots(rows, cols, figsize=(cols * 2, rows * 2))
    axes = axes.ravel()

    for i in range(n_images):
        axes[i].imshow(generated_imgs[i], cmap='gray')
        axes[i].axis('off')

    for j in range(n_images, len(axes)):
        axes[j].axis('off')

    plt.tight_layout()
    plt.show()

# Ejemplo de uso
generate_and_plot_images(generator, LATENT_DIM, n_images=16)

# %% [markdown]
# #Ejercicio 2
#
# Qué se hizo:
#
# se sustituyó MNIST por Fashion MNIST para entrenar la misma GAN y evaluar si podía generar prendas de ropa reconocibles.
#
# Qué se aprendió:
# se entiende que Fashion MNIST es más complejo visualmente, porque las prendas tienen más variación de forma y textura que los dígitos, así que la GAN necesita aprender patrones más difíciles .
#
# Comparación antes/después:
#
# antes la GAN generaba dígitos simples y estructurados; después, al usar Fashion MNIST, la tarea se vuelve más difícil y las salidas pueden ser más ruidosas o menos definidas, aunque permiten comprobar la capacidad del modelo en otro tipo de datos .

# %%
# Cargar Fashion MNIST
(X_train, _), (_, _) = keras.datasets.fashion_mnist.load_data()
X_train = X_train.astype('float32') / 255.0
X_train = X_train.reshape(-1, 28*28)

LATENT_DIM = 100

def build_generator(latent_dim=LATENT_DIM):
    model = keras.Sequential([
        keras.layers.Dense(128, input_dim=latent_dim),
        keras.layers.BatchNormalization(),
        keras.layers.LeakyReLU(0.2),
        keras.layers.Dense(256),
        keras.layers.BatchNormalization(),
        keras.layers.LeakyReLU(0.2),
        keras.layers.Dense(28*28, activation='sigmoid')
    ])
    return model

def build_discriminator():
    model = keras.Sequential([
        keras.layers.Dense(256, input_dim=28*28),
        keras.layers.LeakyReLU(0.2),
        keras.layers.Dense(128),
        keras.layers.LeakyReLU(0.2),
        keras.layers.Dense(1, activation='sigmoid')
    ])
    return model

# Re-crear modelos
generator = build_generator()
discriminator = build_discriminator()
discriminator.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
discriminator.trainable = False

z = keras.Input(shape=(LATENT_DIM,))
img = generator(z)
valid = discriminator(img)
gan = keras.Model(z, valid)
gan.compile(optimizer='adam', loss='binary_crossentropy')

# Entrenar
train_gan(epochs=3000, batch_size=64, sample_interval=500)
# Out:
# Epoch    0/3000 | D loss: 0.7919, acc: 4.7% | G loss: 0.6714 | ⏱ 2.7s
#   ⚠️  Posible mode collapse detectado (similitud promedio: 0.969)
# Epoch  500/3000 | D loss: 3.2876, acc: 0.0% | G loss: 0.0070 | ⏱ 47.4s
#   ⚠️  Posible mode collapse detectado (similitud promedio: 0.970)
# Epoch 1000/3000 | D loss: 3.8199, acc: 0.0% | G loss: 0.0037 | ⏱ 93.0s
#   ⚠️  Posible mode collapse detectado (similitud promedio: 0.972)
# Epoch 1500/3000 | D loss: 4.0932, acc: 0.0% | G loss: 0.0025 | ⏱ 137.8s
#   ⚠️  Posible mode collapse detectado (similitud promedio: 0.974)
# Epoch 2000/3000 | D loss: 4.2742, acc: 0.0% | G loss: 0.0019 | ⏱ 184.6s
#   ⚠️  Posible mode collapse detectado (similitud promedio: 0.975)
# Epoch 2500/3000 | D loss: 4.4081, acc: 0.0% | G loss: 0.0016 | ⏱ 230.8s
#   ⚠️  Posible mode collapse detectado (similitud promedio: 0.976)
#
# ✅ Entrenamiento completo en 275.1s (4.6 min)
# ([np.float32(0.7919358),
#   np.float32(0.79922616),
#   np.float32(0.8304868),
#   np.float32(0.8570903),
#   np.float32(0.8890492),
#   np.float32(0.9222035),
#   np.float32(0.9546349),
#   np.float32(0.9872968),
#   np.float32(1.0178475),
#   np.float32(1.0490363),
#   np.float32(1.079401),
#   np.float32(1.1077144),
#   np.float32(1.1370624),
#   np.float32(1.1636034),
#   np.float32(1.1893005),
#   np.float32(1.2147151),
#   np.float32(1.2382876),
#   np.float32(1.2616698),
#   np.float32(1.2844812),
#   np.float32(1.3064291),
#   np.float32(1.3273265),
#   np.float32(1.3490665),
#   np.float32(1.3696454),
#   np.float32(1.3887066),
#   np.float32(1.4075234),
#   np.float32(1.4259093),
#   np.float32(1.4428203),
#   np.float32(1.4589866),
#   np.float32(1.4754537),
#   np.float32(1.4915174),
#   np.float32(1.507278),
#   np.float32(1.522043),
#   np.float32(1.5369208),
#   np.float32(1.5508423),
#   np.float32(1.5644181),
#   np.float32(1.5774196),
#   np.float32(1.5900962),
#   np.float32(1.6018829),
#   np.float32(1.6147718),
#   np.float32(1.6269989),
#   np.float32(1.6387091),
#   np.float32(1.6491387),
#   np.float32(1.6594883),
#   np.float32(1.6698327),
#   np.float32(1.67978),
#   np.float32(1.6900134),
#   np.float32(1.6998986),
#   np.float32(1.7094992),
#   np.float32(1.7185245),
#   np.float32(1.727983),
#   np.float32(1.7367293),
#   np.float32(1.7450819),
#   np.float32(1.7535102),
#   np.float32(1.7622652),
#   np.float32(1.7710694),
#   np.float32(1.7788465),
#   np.float32(1.786818),
#   np.float32(1.7949674),
#   np.float32(1.8028163),
#   np.float32(1.810075),
#   np.float32(1.8181214),
#   np.float32(1.8266704),
#   np.float32(1.8347349),
#   np.float32(1.842481),
#   np.float32(1.8502927),
#   np.float32(1.8577206),
#   np.float32(1.8646479),
#   np.float32(1.8714432),
#   np.float32(1.8785639),
#   np.float32(1.8857442),
#   np.float32(1.8929193),
#   np.float32(1.900089),
#   np.float32(1.9069774),
#   np.float32(1.9138348),
#   np.float32(1.9205902),
#   np.float32(1.9269347),
#   np.float32(1.9329014),
#   np.float32(1.9389358),
#   np.float32(1.9450259),
#   np.float32(1.9511286),
#   np.float32(1.9574958),
#   np.float32(1.9640034),
#   np.float32(1.9698567),
#   np.float32(1.9755738),
#   np.float32(1.9813337),
#   np.float32(1.9868921),
#   np.float32(1.9927988),
#   np.float32(1.998735),
#   np.float32(2.0045943),
#   np.float32(2.0107884),
#   np.float32(2.0168407),
#   np.float32(2.0228198),
#   np.float32(2.0284657),
#   np.float32(2.033737),
#   np.float32(2.039273),
#   np.float32(2.045002),
#   np.float32(2.0504823),
#   np.float32(2.0554795),
#   np.float32(2.0607727),
#   np.float32(2.0663962),
#   np.float32(2.0718656),
#   np.float32(2.0773866),
#   np.float32(2.082696),
#   np.float32(2.0877833),
#   np.float32(2.0934615),
#   np.float32(2.098633),
#   np.float32(2.1033988),
#   np.float32(2.1084075),
#   np.float32(2.113655),
#   np.float32(2.1188254),
#   np.float32(2.1239576),
#   np.float32(2.1288784),
#   np.float32(2.134015),
#   np.float32(2.139159),
#   np.float32(2.14423),
#   np.float32(2.149323),
#   np.float32(2.154232),
#   np.float32(2.159114),
#   np.float32(2.1641252),
#   np.float32(2.1690583),
#   np.float32(2.1739674),
#   np.float32(2.1789484),
#   np.float32(2.1840205),
#   np.float32(2.1888134),
#   np.float32(2.193427),
#   np.float32(2.1977034),
#   np.float32(2.202135),
#   np.float32(2.2067397),
#   np.float32(2.211554),
#   np.float32(2.216613),
#   np.float32(2.2213743),
#   np.float32(2.225994),
#   np.float32(2.2306173),
#   np.float32(2.2356067),
#   np.float32(2.2405906),
#   np.float32(2.2453241),
#   np.float32(2.2499933),
#   np.float32(2.2545767),
#   np.float32(2.2591524),
#   np.float32(2.2638679),
#   np.float32(2.268539),
#   np.float32(2.273107),
#   np.float32(2.2775435),
#   np.float32(2.2819552),
#   np.float32(2.2863085),
#   np.float32(2.2907362),
#   np.float32(2.2950292),
#   np.float32(2.2993414),
#   np.float32(2.3036878),
#   np.float32(2.3079267),
#   np.float32(2.312138),
#   np.float32(2.3164682),
#   np.float32(2.3209074),
#   np.float32(2.3253088),
#   np.float32(2.3297334),
#   np.float32(2.3343015),
#   np.float32(2.3385587),
#   np.float32(2.3425996),
#   np.float32(2.3468125),
#   np.float32(2.351111),
#   np.float32(2.355352),
#   np.float32(2.3595414),
#   np.float32(2.3637424),
#   np.float32(2.3678463),
#   np.float32(2.3719425),
#   np.float32(2.376172),
#   np.float32(2.380501),
#   np.float32(2.3847637),
#   np.float32(2.3889825),
#   np.float32(2.393252),
#   np.float32(2.397523),
#   np.float32(2.4018013),
#   np.float32(2.4060373),
#   np.float32(2.4102786),
#   np.float32(2.4144394),
#   np.float32(2.4184718),
#   np.float32(2.4225273),
#   np.float32(2.4265485),
#   np.float32(2.4305606),
#   np.float32(2.4346085),
#   np.float32(2.4386659),
#   np.float32(2.4427044),
#   np.float32(2.4469144),
#   np.float32(2.450925),
#   np.float32(2.454669),
#   np.float32(2.458619),
#   np.float32(2.4628084),
#   np.float32(2.466862),
#   np.float32(2.470777),
#   np.float32(2.474684),
#   np.float32(2.4784284),
#   np.float32(2.482287),
#   np.float32(2.4860876),
#   np.float32(2.489925),
#   np.float32(2.4938807),
#   np.float32(2.4978266),
#   np.float32(2.5015821),
#   np.float32(2.5054836),
#   np.float32(2.50942),
#   np.float32(2.513241),
#   np.float32(2.516994),
#   np.float32(2.520876),
#   np.float32(2.5247982),
#   np.float32(2.5286806),
#   np.float32(2.5325873),
#   np.float32(2.5363564),
#   np.float32(2.5402927),
#   np.float32(2.5441122),
#   np.float32(2.5478315),
#   np.float32(2.551677),
#   np.float32(2.5555313),
#   np.float32(2.5593524),
#   np.float32(2.5630965),
#   np.float32(2.566898),
#   np.float32(2.5705853),
#   np.float32(2.57419),
#   np.float32(2.577742),
#   np.float32(2.5813622),
#   np.float32(2.585012),
#   np.float32(2.5885987),
#   np.float32(2.592239),
#   np.float32(2.596013),
#   np.float32(2.5995963),
#   np.float32(2.6030164),
#   np.float32(2.6066108),
#   np.float32(2.610227),
#   np.float32(2.6136208),
#   np.float32(2.617108),
#   np.float32(2.6205719),
#   np.float32(2.6241145),
#   np.float32(2.6277115),
#   np.float32(2.6312485),
#   np.float32(2.634793),
#   np.float32(2.6382046),
#   np.float32(2.641461),
#   np.float32(2.6448686),
#   np.float32(2.6482475),
#   np.float32(2.6515946),
#   np.float32(2.6549687),
#   np.float32(2.6582913),
#   np.float32(2.6616592),
#   np.float32(2.66502),
#   np.float32(2.6682863),
#   np.float32(2.6715646),
#   np.float32(2.6748993),
#   np.float32(2.6780977),
#   np.float32(2.6812987),
#   np.float32(2.6846602),
#   np.float32(2.688033),
#   np.float32(2.691444),
#   np.float32(2.6947052),
#   np.float32(2.6980615),
#   np.float32(2.701284),
#   np.float32(2.7043614),
#   np.float32(2.7074146),
#   np.float32(2.7105217),
#   np.float32(2.7137465),
#   np.float32(2.7169554),
#   np.float32(2.7201436),
#   np.float32(2.723324),
#   np.float32(2.726622),
#   np.float32(2.730063),
#   np.float32(2.7334423),
#   np.float32(2.7366428),
#   np.float32(2.7397542),
#   np.float32(2.7429624),
#   np.float32(2.7461512),
#   np.float32(2.7492628),
#   np.float32(2.7524424),
#   np.float32(2.7555962),
#   np.float32(2.758708),
#   np.float32(2.7618747),
#   np.float32(2.7650254),
#   np.float32(2.768194),
#   np.float32(2.7714002),
#   np.float32(2.7745252),
#   np.float32(2.777626),
#   np.float32(2.7807572),
#   np.float32(2.7839327),
#   np.float32(2.7869449),
#   np.float32(2.7900672),
#   np.float32(2.7931426),
#   np.float32(2.7961698),
#   np.float32(2.799192),
#   np.float32(2.8021598),
#   np.float32(2.8052611),
#   np.float32(2.8082657),
#   np.float32(2.8112175),
#   np.float32(2.814196),
#   np.float32(2.817193),
#   np.float32(2.8201857),
#   np.float32(2.8232005),
#   np.float32(2.8261683),
#   np.float32(2.8290772),
#   np.float32(2.8319468),
#   np.float32(2.8347957),
#   np.float32(2.8377848),
#   np.float32(2.8407073),
#   np.float32(2.8436375),
#   np.float32(2.8464966),
#   np.float32(2.849391),
#   np.float32(2.8522325),
#   np.float32(2.8550236),
#   np.float32(2.8577962),
#   np.float32(2.8605855),
#   np.float32(2.8633184),
#   np.float32(2.8661711),
#   np.float32(2.8690262),
#   np.float32(2.8718462),
#   np.float32(2.8746257),
#   np.float32(2.8773823),
#   np.float32(2.8802338),
#   np.float32(2.883046),
#   np.float32(2.8857923),
#   np.float32(2.8885527),
#   np.float32(2.8912249),
#   np.float32(2.8940158),
#   np.float32(2.8967767),
#   np.float32(2.8995438),
#   np.float32(2.902358),
#   np.float32(2.9051504),
#   np.float32(2.9078593),
#   np.float32(2.9104843),
#   np.float32(2.9131827),
#   np.float32(2.9158268),
#   np.float32(2.9183745),
#   np.float32(2.920981),
#   np.float32(2.9237409),
#   np.float32(2.9264336),
#   np.float32(2.9290662),
#   np.float32(2.931788),
#   np.float32(2.934382),
#   np.float32(2.9369946),
#   np.float32(2.9395852),
#   np.float32(2.9421995),
#   np.float32(2.9448085),
#   np.float32(2.9474006),
#   np.float32(2.949944),
#   np.float32(2.9525),
#   np.float32(2.955137),
#   np.float32(2.9578009),
#   np.float32(2.960368),
#   np.float32(2.9629405),
#   np.float32(2.965508),
#   np.float32(2.9679782),
#   np.float32(2.9704866),
#   np.float32(2.9729402),
#   np.float32(2.9753919),
#   np.float32(2.9778838),
#   np.float32(2.9804342),
#   np.float32(3.5357766),
#   np.float32(3.536935),
#   np.float32(3.538097),
#   np.float32(3.5391974),
#   np.float32(3.540302),
#   np.float32(3.5414543),
#   np.float32(3.5426044),
#   np.float32(3.5437517),
#   np.float32(3.5448718),
#   np.float32(3.5459743),
#   np.float32(3.5471187),
#   np.float32(3.548264),
#   np.float32(3.5494003),
#   np.float32(3.55051),
#   np.float32(3.5516152),
#   np.float32(3.5527215),
#   np.float32(3.5538573),
#   np.float32(3.5550098),
#   np.float32(3.556137),
#   np.float32(3.557258),
#   np.float32(3.558385),
#   np.float32(3.5594788),
#   np.float32(3.5605814),
#   np.float32(3.5617304),
#   np.float32(3.5628703),
#   np.float32(3.5639813),
#   np.float32(3.56509),
#   np.float32(3.5661619),
#   np.float32(3.5672073),
#   np.float32(3.5682964),
#   np.float32(3.5693529),
#   np.float32(3.5704315),
#   np.float32(3.5715036),
#   np.float32(3.5725417),
#   np.float32(3.5736032),
#   np.float32(3.574678),
#   np.float32(3.5757165),
#   np.float32(3.5767584),
#   np.float32(3.5777953),
#   np.float32(3.5788517),
#   np.float32(3.5799205),
#   np.float32(3.5809855),
#   np.float32(3.5820522),
#   np.float32(3.583096),
#   np.float32(3.5841699),
#   np.float32(3.5852368),
#   np.float32(3.5862868),
#   np.float32(3.5873208),
#   np.float32(3.5883737),
#   np.float32(3.5894196),
#   np.float32(3.5904603),
#   np.float32(3.5915027),
#   np.float32(3.592547),
#   np.float32(3.5936098),
#   np.float32(3.5946846),
#   np.float32(3.5957315),
#   np.float32(3.5967276),
#   np.float32(3.5977383),
#   np.float32(3.5987449),
#   np.float32(3.5997329),
#   np.float32(3.600731),
#   np.float32(3.6017647),
#   np.float32(3.6027782),
#   np.float32(3.6037898),
#   np.float32(3.604814),
#   np.float32(3.6058478),
#   np.float32(3.606843),
#   np.float32(3.6078465),
#   np.float32(3.6088557),
#   np.float32(3.6098437),
#   np.float32(3.610825),
#   np.float32(3.6118314),
#   np.float32(3.612827),
#   np.float32(3.6138508),
#   np.float32(3.6148806),
#   np.float32(3.6159117),
#   np.float32(3.6169138),
#   np.float32(3.6179142),
#   np.float32(3.6189399),
#   np.float32(3.6199217),
#   np.float32(3.620895),
#   np.float32(3.6218839),
#   np.float32(3.622843),
#   np.float32(3.6238241),
#   np.float32(3.6247993),
#   np.float32(3.6257954),
#   np.float32(3.626771),
#   np.float32(3.6277218),
#   np.float32(3.6286728),
#   np.float32(3.62962),
#   np.float32(3.6305802),
#   np.float32(3.6315432),
#   np.float32(3.6325054),
#   np.float32(3.6334872),
#   np.float32(3.6344438),
#   np.float32(3.635453),
#   np.float32(3.6364388),
#   np.float32(3.6374211),
#   np.float32(3.6383853),
#   np.float32(3.6393511),
#   np.float32(3.6403062),
#   np.float32(3.641274),
#   np.float32(3.642228),
#   np.float32(3.643187),
#   np.float32(3.644123),
#   np.float32(3.6450782),
#   np.float32(3.6460142),
#   np.float32(3.646954),
#   np.float32(3.6479144),
#   np.float32(3.6488678),
#   np.float32(3.6497967),
#   np.float32(3.7458694),
#   np.float32(3.7466702),
#   np.float32(3.747468),
#   np.float32(3.7482705),
#   np.float32(3.7490814),
#   np.float32(3.7498896),
#   np.float32(3.7506685),
#   np.float32(3.7514791),
#   np.float32(3.7522926),
#   np.float32(3.753096),
#   np.float32(3.7538846),
#   np.float32(3.7546682),
#   np.float32(3.7554572),
#   np.float32(3.7562199),
#   np.float32(3.7569952),
#   np.float32(3.7577724),
#   np.float32(3.7585542),
#   np.float32(3.7593265),
#   np.float32(3.7601094),
#   np.float32(3.7608786),
#   np.float32(3.76163),
#   np.float32(3.7623973),
#   np.float32(3.7631862),
#   np.float32(3.7639725),
#   np.float32(3.7647614),
#   np.float32(3.7655282),
#   np.float32(3.7662773),
#   np.float32(3.7670288),
#   np.float32(3.767808),
#   np.float32(3.7686057),
#   np.float32(3.7693713),
#   np.float32(3.7701101),
#   np.float32(3.7708774),
#   np.float32(3.7716482),
#   np.float32(3.772393),
#   np.float32(3.773148),
#   np.float32(3.7739186),
#   np.float32(3.7746778),
#   np.float32(3.7754202),
#   np.float32(3.7761836),
#   np.float32(3.7769432),
#   np.float32(3.7777064),
#   np.float32(3.7784784),
#   np.float32(3.779251),
#   np.float32(3.7800078),
#   np.float32(3.7807736),
#   np.float32(3.7815204),
#   np.float32(3.7822757),
#   np.float32(3.7830276),
#   np.float32(3.783777),
#   np.float32(3.78451),
#   np.float32(3.7852569),
#   np.float32(3.7859988),
#   np.float32(3.7867365),
#   np.float32(3.7874808),
#   np.float32(3.7882438),
#   np.float32(3.7890105),
#   np.float32(3.7897577),
#   np.float32(3.790501),
#   np.float32(3.7912638),
#   np.float32(3.7920005),
#   np.float32(3.792738),
#   np.float32(3.7934775),
#   np.float32(3.7942019),
#   np.float32(3.7949448),
#   np.float32(3.7956932),
#   np.float32(3.7964144),
#   np.float32(3.7971406),
#   np.float32(3.797872),
#   np.float32(3.7986012),
#   np.float32(3.7993286),
#   np.float32(3.800044),
#   np.float32(3.8007693),
#   np.float32(3.8014948),
#   np.float32(3.802212),
#   np.float32(3.8029237),
#   np.float32(3.8036325),
#   np.float32(3.8043299),
#   np.float32(3.8050709),
#   np.float32(3.8058004),
#   np.float32(3.8064938),
#   np.float32(3.8072023),
#   np.float32(3.8079257),
#   np.float32(3.8086505),
#   np.float32(3.809356),
#   np.float32(3.810064),
#   np.float32(3.8107665),
#   np.float32(3.8114738),
#   np.float32(3.8121846),
#   np.float32(3.8128967),
#   np.float32(3.8135972),
#   np.float32(3.8143024),
#   np.float32(3.8149843),
#   np.float32(3.815683),
#   np.float32(3.8164017),
#   np.float32(3.817111),
#   np.float32(3.8178115),
#   np.float32(3.8185048),
#   np.float32(3.8192134),
#   ...],
#  [array(0.6713572, dtype=float32),
#   array(0.56829333, dtype=float32),
#   array(0.48978555, dtype=float32),
#   array(0.42878836, dtype=float32),
#   array(0.3799912, dtype=float32),
#   array(0.34043097, dtype=float32),
#   array(0.30783176, dtype=float32),
#   array(0.28047076, dtype=float32),
#   array(0.25721028, dtype=float32),
#   array(0.23739931, dtype=float32),
#   array(0.22030592, dtype=float32),
#   array(0.20548733, dtype=float32),
#   array(0.192466, dtype=float32),
#   array(0.18097751, dtype=float32),
#   array(0.17077844, dtype=float32),
#   array(0.16164626, dtype=float32),
#   array(0.15345442, dtype=float32),
#   array(0.14604728, dtype=float32),
#   array(0.13933022, dtype=float32),
#   array(0.13316084, dtype=float32),
#   array(0.12752955, dtype=float32),
#   array(0.12235986, dtype=float32),
#   array(0.11760275, dtype=float32),
#   array(0.11319254, dtype=float32),
#   array(0.10911342, dtype=float32),
#   array(0.10532172, dtype=float32),
#   array(0.10179587, dtype=float32),
#   array(0.09849521, dtype=float32),
#   array(0.09540451, dtype=float32),
#   array(0.09251152, dtype=float32),
#   array(0.0897912, dtype=float32),
#   array(0.08723153, dtype=float32),
#   array(0.08481578, dtype=float32),
#   array(0.08254274, dtype=float32),
#   array(0.08038472, dtype=float32),
#   array(0.0783434, dtype=float32),
#   array(0.07640751, dtype=float32),
#   array(0.07456702, dtype=float32),
#   array(0.07281552, dtype=float32),
#   array(0.07114796, dtype=float32),
#   array(0.06955715, dtype=float32),
#   array(0.06803604, dtype=float32),
#   array(0.06658421, dtype=float32),
#   array(0.06519615, dtype=float32),
#   array(0.06386478, dtype=float32),
#   array(0.0625879, dtype=float32),
#   array(0.06136771, dtype=float32),
#   array(0.06019508, dtype=float32),
#   array(0.05906546, dtype=float32),
#   array(0.05798186, dtype=float32),
#   array(0.05693892, dtype=float32),
#   array(0.05593437, dtype=float32),
#   array(0.0549665, dtype=float32),
#   array(0.05403604, dtype=float32),
#   array(0.05313508, dtype=float32),
#   array(0.05226286, dtype=float32),
#   array(0.0514226, dtype=float32),
#   array(0.05061018, dtype=float32),
#   array(0.04982429, dtype=float32),
#   array(0.04906517, dtype=float32),
#   array(0.0483276, dtype=float32),
#   array(0.04761483, dtype=float32),
#   array(0.0469221, dtype=float32),
#   array(0.04625164, dtype=float32),
#   array(0.04559971, dtype=float32),
#   array(0.04496843, dtype=float32),
#   array(0.0443522, dtype=float32),
#   array(0.04375621, dtype=float32),
#   array(0.04317594, dtype=float32),
#   array(0.04261202, dtype=float32),
#   array(0.04206137, dtype=float32),
#   array(0.04152607, dtype=float32),
#   array(0.04100513, dtype=float32),
#   array(0.04049836, dtype=float32),
#   array(0.04000414, dtype=float32),
#   array(0.03952322, dtype=float32),
#   array(0.03905286, dtype=float32),
#   array(0.0385948, dtype=float32),
#   array(0.03814803, dtype=float32),
#   array(0.03771212, dtype=float32),
#   array(0.03728595, dtype=float32),
#   array(0.03687026, dtype=float32),
#   array(0.03646395, dtype=float32),
#   array(0.0360674, dtype=float32),
#   array(0.03567954, dtype=float32),
#   array(0.03530096, dtype=float32),
#   array(0.03492995, dtype=float32),
#   array(0.03456773, dtype=float32),
#   array(0.03421286, dtype=float32),
#   array(0.03386514, dtype=float32),
#   array(0.03352543, dtype=float32),
#   array(0.03319271, dtype=float32),
#   array(0.03286663, dtype=float32),
#   array(0.03254772, dtype=float32),
#   array(0.03223541, dtype=float32),
#   array(0.03192863, dtype=float32),
#   array(0.03162829, dtype=float32),
#   array(0.0313336, dtype=float32),
#   array(0.0310448, dtype=float32),
#   array(0.03076158, dtype=float32),
#   array(0.03048366, dtype=float32),
#   array(0.03021107, dtype=float32),
#   array(0.02994341, dtype=float32),
#   array(0.02968051, dtype=float32),
#   array(0.02942247, dtype=float32),
#   array(0.02916888, dtype=float32),
#   array(0.0289199, dtype=float32),
#   array(0.02867604, dtype=float32),
#   array(0.02843625, dtype=float32),
#   array(0.02820046, dtype=float32),
#   array(0.02796854, dtype=float32),
#   array(0.02774077, dtype=float32),
#   array(0.0275169, dtype=float32),
#   array(0.02729695, dtype=float32),
#   array(0.02708094, dtype=float32),
#   array(0.02686814, dtype=float32),
#   array(0.02665866, dtype=float32),
#   array(0.02645248, dtype=float32),
#   array(0.02624919, dtype=float32),
#   array(0.02604944, dtype=float32),
#   array(0.0258527, dtype=float32),
#   array(0.02565929, dtype=float32),
#   array(0.02546886, dtype=float32),
#   array(0.02528136, dtype=float32),
#   array(0.02509614, dtype=float32),
#   array(0.02491445, dtype=float32),
#   array(0.02473563, dtype=float32),
#   array(0.02455947, dtype=float32),
#   array(0.02438524, dtype=float32),
#   array(0.02421414, dtype=float32),
#   array(0.02404562, dtype=float32),
#   array(0.02387967, dtype=float32),
#   array(0.02371573, dtype=float32),
#   array(0.02355429, dtype=float32),
#   array(0.02339483, dtype=float32),
#   array(0.02323812, dtype=float32),
#   array(0.02308327, dtype=float32),
#   array(0.02293083, dtype=float32),
#   array(0.02278034, dtype=float32),
#   array(0.02263186, dtype=float32),
#   array(0.02248536, dtype=float32),
#   array(0.02234088, dtype=float32),
#   array(0.02219847, dtype=float32),
#   array(0.02205787, dtype=float32),
#   array(0.02191871, dtype=float32),
#   array(0.02178188, dtype=float32),
#   array(0.02164644, dtype=float32),
#   array(0.02151301, dtype=float32),
#   array(0.0213812, dtype=float32),
#   array(0.02125105, dtype=float32),
#   array(0.02112225, dtype=float32),
#   array(0.02099534, dtype=float32),
#   array(0.02087005, dtype=float32),
#   array(0.02074627, dtype=float32),
#   array(0.02062432, dtype=float32),
#   array(0.0205036, dtype=float32),
#   array(0.02038441, dtype=float32),
#   array(0.02026653, dtype=float32),
#   array(0.0201504, dtype=float32),
#   array(0.02003556, dtype=float32),
#   array(0.01992193, dtype=float32),
#   array(0.01980958, dtype=float32),
#   array(0.01969865, dtype=float32),
#   array(0.01958919, dtype=float32),
#   array(0.01948069, dtype=float32),
#   array(0.01937338, dtype=float32),
#   array(0.01926756, dtype=float32),
#   array(0.01916271, dtype=float32),
#   array(0.01905911, dtype=float32),
#   array(0.01895665, dtype=float32),
#   array(0.01885531, dtype=float32),
#   array(0.0187552, dtype=float32),
#   array(0.01865605, dtype=float32),
#   array(0.01855789, dtype=float32),
#   array(0.01846092, dtype=float32),
#   array(0.01836511, dtype=float32),
#   array(0.0182703, dtype=float32),
#   array(0.01817657, dtype=float32),
#   array(0.01808371, dtype=float32),
#   array(0.01799199, dtype=float32),
#   array(0.01790101, dtype=float32),
#   array(0.01781096, dtype=float32),
#   array(0.01772214, dtype=float32),
#   array(0.01763402, dtype=float32),
#   array(0.01754681, dtype=float32),
#   array(0.01746056, dtype=float32),
#   array(0.0173752, dtype=float32),
#   array(0.01729077, dtype=float32),
#   array(0.01720706, dtype=float32),
#   array(0.01712424, dtype=float32),
#   array(0.01704233, dtype=float32),
#   array(0.01696115, dtype=float32),
#   array(0.0168806, dtype=float32),
#   array(0.01680089, dtype=float32),
#   array(0.01672216, dtype=float32),
#   array(0.01664413, dtype=float32),
#   array(0.0165667, dtype=float32),
#   array(0.01649009, dtype=float32),
#   array(0.0164142, dtype=float32),
#   array(0.01633895, dtype=float32),
#   array(0.01626468, dtype=float32),
#   array(0.01619097, dtype=float32),
#   array(0.01611791, dtype=float32),
#   array(0.0160456, dtype=float32),
#   array(0.01597383, dtype=float32),
#   array(0.01590275, dtype=float32),
#   array(0.01583257, dtype=float32),
#   array(0.01576279, dtype=float32),
#   array(0.01569385, dtype=float32),
#   array(0.01562542, dtype=float32),
#   array(0.01555768, dtype=float32),
#   array(0.01549039, dtype=float32),
#   array(0.0154238, dtype=float32),
#   array(0.0153578, dtype=float32),
#   array(0.0152924, dtype=float32),
#   array(0.01522761, dtype=float32),
#   array(0.01516332, dtype=float32),
#   array(0.01509965, dtype=float32),
#   array(0.01503669, dtype=float32),
#   array(0.01497419, dtype=float32),
#   array(0.01491211, dtype=float32),
#   array(0.01485059, dtype=float32),
#   array(0.01478957, dtype=float32),
#   array(0.01472912, dtype=float32),
#   array(0.0146692, dtype=float32),
#   array(0.01460984, dtype=float32),
#   array(0.01455082, dtype=float32),
#   array(0.01449238, dtype=float32),
#   array(0.01443436, dtype=float32),
#   array(0.01437674, dtype=float32),
#   array(0.01431965, dtype=float32),
#   array(0.01426303, dtype=float32),
#   array(0.01420682, dtype=float32),
#   array(0.01415114, dtype=float32),
#   array(0.01409597, dtype=float32),
#   array(0.01404134, dtype=float32),
#   array(0.01398699, dtype=float32),
#   array(0.01393303, dtype=float32),
#   array(0.01387951, dtype=float32),
#   array(0.01382649, dtype=float32),
#   array(0.01377382, dtype=float32),
#   array(0.01372157, dtype=float32),
#   array(0.01366981, dtype=float32),
#   array(0.01361838, dtype=float32),
#   array(0.01356741, dtype=float32),
#   array(0.01351681, dtype=float32),
#   array(0.01346666, dtype=float32),
#   array(0.01341685, dtype=float32),
#   array(0.01336746, dtype=float32),
#   array(0.01331838, dtype=float32),
#   array(0.01326968, dtype=float32),
#   array(0.01322139, dtype=float32),
#   array(0.01317341, dtype=float32),
#   array(0.01312578, dtype=float32),
#   array(0.01307851, dtype=float32),
#   array(0.01303161, dtype=float32),
#   array(0.01298506, dtype=float32),
#   array(0.01293887, dtype=float32),
#   array(0.012893, dtype=float32),
#   array(0.01284748, dtype=float32),
#   array(0.01280235, dtype=float32),
#   array(0.01275751, dtype=float32),
#   array(0.01271297, dtype=float32),
#   array(0.01266873, dtype=float32),
#   array(0.01262485, dtype=float32),
#   array(0.0125813, dtype=float32),
#   array(0.01253802, dtype=float32),
#   array(0.0124951, dtype=float32),
#   array(0.01245249, dtype=float32),
#   array(0.01241011, dtype=float32),
#   array(0.01236805, dtype=float32),
#   array(0.01232636, dtype=float32),
#   array(0.0122849, dtype=float32),
#   array(0.01224371, dtype=float32),
#   array(0.01220282, dtype=float32),
#   array(0.01216217, dtype=float32),
#   array(0.01212188, dtype=float32),
#   array(0.01208184, dtype=float32),
#   array(0.01204211, dtype=float32),
#   array(0.01200265, dtype=float32),
#   array(0.01196343, dtype=float32),
#   array(0.01192448, dtype=float32),
#   array(0.01188579, dtype=float32),
#   array(0.01184732, dtype=float32),
#   array(0.01180913, dtype=float32),
#   array(0.01177127, dtype=float32),
#   array(0.01173359, dtype=float32),
#   array(0.01169618, dtype=float32),
#   array(0.01165898, dtype=float32),
#   array(0.01162203, dtype=float32),
#   array(0.01158534, dtype=float32),
#   array(0.01154886, dtype=float32),
#   array(0.01151267, dtype=float32),
#   array(0.0114767, dtype=float32),
#   array(0.01144096, dtype=float32),
#   array(0.01140545, dtype=float32),
#   array(0.01137022, dtype=float32),
#   array(0.01133518, dtype=float32),
#   array(0.01130036, dtype=float32),
#   array(0.01126576, dtype=float32),
#   array(0.01123142, dtype=float32),
#   array(0.01119724, dtype=float32),
#   array(0.01116327, dtype=float32),
#   array(0.01112953, dtype=float32),
#   array(0.01109601, dtype=float32),
#   array(0.01106275, dtype=float32),
#   array(0.0110297, dtype=float32),
#   array(0.01099678, dtype=float32),
#   array(0.01096411, dtype=float32),
#   array(0.01093173, dtype=float32),
#   array(0.01089943, dtype=float32),
#   array(0.01086734, dtype=float32),
#   array(0.01083546, dtype=float32),
#   array(0.01080368, dtype=float32),
#   array(0.01077214, dtype=float32),
#   array(0.01074081, dtype=float32),
#   array(0.01070966, dtype=float32),
#   array(0.01067872, dtype=float32),
#   array(0.01064794, dtype=float32),
#   array(0.01061734, dtype=float32),
#   array(0.01058691, dtype=float32),
#   array(0.0105567, dtype=float32),
#   array(0.01052666, dtype=float32),
#   array(0.01049674, dtype=float32),
#   array(0.010467, dtype=float32),
#   array(0.01043747, dtype=float32),
#   array(0.01040813, dtype=float32),
#   array(0.0103789, dtype=float32),
#   array(0.01034988, dtype=float32),
#   array(0.01032101, dtype=float32),
#   array(0.01029232, dtype=float32),
#   array(0.01026382, dtype=float32),
#   array(0.01023549, dtype=float32),
#   array(0.01020732, dtype=float32),
#   array(0.01017932, dtype=float32),
#   array(0.01015144, dtype=float32),
#   array(0.01012377, dtype=float32),
#   array(0.01009621, dtype=float32),
#   array(0.01006882, dtype=float32),
#   array(0.01004158, dtype=float32),
#   array(0.0100145, dtype=float32),
#   array(0.00998755, dtype=float32),
#   array(0.00996076, dtype=float32),
#   array(0.00993412, dtype=float32),
#   array(0.00990761, dtype=float32),
#   array(0.00988127, dtype=float32),
#   array(0.00985509, dtype=float32),
#   array(0.00982905, dtype=float32),
#   array(0.00980315, dtype=float32),
#   array(0.00977738, dtype=float32),
#   array(0.00975174, dtype=float32),
#   array(0.00972623, dtype=float32),
#   array(0.00970087, dtype=float32),
#   array(0.00967564, dtype=float32),
#   array(0.00965053, dtype=float32),
#   array(0.00962559, dtype=float32),
#   array(0.00960075, dtype=float32),
#   array(0.00957608, dtype=float32),
#   array(0.00955151, dtype=float32),
#   array(0.00952708, dtype=float32),
#   array(0.00950279, dtype=float32),
#   array(0.00947861, dtype=float32),
#   array(0.00945458, dtype=float32),
#   array(0.00943068, dtype=float32),
#   array(0.00940689, dtype=float32),
#   array(0.00938324, dtype=float32),
#   array(0.00935971, dtype=float32),
#   array(0.0093363, dtype=float32),
#   array(0.00931299, dtype=float32),
#   array(0.00928979, dtype=float32),
#   array(0.00926671, dtype=float32),
#   array(0.00924373, dtype=float32),
#   array(0.00922088, dtype=float32),
#   array(0.00919817, dtype=float32),
#   array(0.00917562, dtype=float32),
#   array(0.00915312, dtype=float32),
#   array(0.00913073, dtype=float32),
#   array(0.00910851, dtype=float32),
#   array(0.00908637, dtype=float32),
#   array(0.00906432, dtype=float32),
#   array(0.00904239, dtype=float32),
#   array(0.00902059, dtype=float32),
#   array(0.00899889, dtype=float32),
#   array(0.00897728, dtype=float32),
#   array(0.00895579, dtype=float32),
#   array(0.00893442, dtype=float32),
#   array(0.00891319, dtype=float32),
#   array(0.00889202, dtype=float32),
#   array(0.00887096, dtype=float32),
#   array(0.00885, dtype=float32),
#   array(0.00882915, dtype=float32),
#   array(0.00880841, dtype=float32),
#   array(0.00878774, dtype=float32),
#   array(0.00876719, dtype=float32),
#   array(0.00874678, dtype=float32),
#   array(0.00872644, dtype=float32),
#   array(0.00870617, dtype=float32),
#   array(0.00868599, dtype=float32),
#   array(0.00866592, dtype=float32),
#   array(0.00864595, dtype=float32),
#   array(0.00862606, dtype=float32),
#   array(0.00860629, dtype=float32),
#   array(0.00858658, dtype=float32),
#   array(0.00856698, dtype=float32),
#   array(0.00854752, dtype=float32),
#   array(0.0085281, dtype=float32),
#   array(0.00850879, dtype=float32),
#   array(0.0084896, dtype=float32),
#   array(0.00847046, dtype=float32),
#   array(0.00845142, dtype=float32),
#   array(0.00843245, dtype=float32),
#   array(0.0084136, dtype=float32),
#   array(0.00839481, dtype=float32),
#   array(0.00837612, dtype=float32),
#   array(0.0083575, dtype=float32),
#   array(0.00833896, dtype=float32),
#   array(0.00832052, dtype=float32),
#   array(0.00830218, dtype=float32),
#   array(0.00828393, dtype=float32),
#   array(0.00826577, dtype=float32),
#   array(0.00824766, dtype=float32),
#   array(0.00822964, dtype=float32),
#   array(0.00821169, dtype=float32),
#   array(0.00819383, dtype=float32),
#   array(0.00817604, dtype=float32),
#   array(0.00815835, dtype=float32),
#   array(0.00814073, dtype=float32),
#   array(0.00812317, dtype=float32),
#   array(0.0081057, dtype=float32),
#   array(0.00808833, dtype=float32),
#   array(0.00807101, dtype=float32),
#   array(0.00805379, dtype=float32),
#   array(0.00803663, dtype=float32),
#   array(0.00801954, dtype=float32),
#   array(0.00800253, dtype=float32),
#   array(0.00798559, dtype=float32),
#   array(0.00796873, dtype=float32),
#   array(0.00795197, dtype=float32),
#   array(0.00793526, dtype=float32),
#   array(0.00791863, dtype=float32),
#   array(0.00790205, dtype=float32),
#   array(0.00788555, dtype=float32),
#   array(0.00786913, dtype=float32),
#   array(0.00785276, dtype=float32),
#   array(0.00783649, dtype=float32),
#   array(0.00782028, dtype=float32),
#   array(0.00780413, dtype=float32),
#   array(0.00778805, dtype=float32),
#   array(0.00777206, dtype=float32),
#   array(0.00775614, dtype=float32),
#   array(0.00774027, dtype=float32),
#   array(0.00772447, dtype=float32),
#   array(0.00770874, dtype=float32),
#   array(0.00769309, dtype=float32),
#   array(0.00767749, dtype=float32),
#   array(0.00766193, dtype=float32),
#   array(0.00764647, dtype=float32),
#   array(0.00763106, dtype=float32),
#   array(0.00761573, dtype=float32),
#   array(0.00760044, dtype=float32),
#   array(0.00758522, dtype=float32),
#   array(0.00757005, dtype=float32),
#   array(0.00755495, dtype=float32),
#   array(0.00753992, dtype=float32),
#   array(0.00752498, dtype=float32),
#   array(0.00751007, dtype=float32),
#   array(0.00749522, dtype=float32),
#   array(0.00748044, dtype=float32),
#   array(0.00746569, dtype=float32),
#   array(0.00745103, dtype=float32),
#   array(0.00743643, dtype=float32),
#   array(0.00742189, dtype=float32),
#   array(0.00740738, dtype=float32),
#   array(0.00739298, dtype=float32),
#   array(0.00737861, dtype=float32),
#   array(0.00736428, dtype=float32),
#   array(0.00735004, dtype=float32),
#   array(0.00733585, dtype=float32),
#   array(0.00732172, dtype=float32),
#   array(0.00730763, dtype=float32),
#   array(0.00729359, dtype=float32),
#   array(0.00727961, dtype=float32),
#   array(0.00726571, dtype=float32),
#   array(0.00725186, dtype=float32),
#   array(0.00723806, dtype=float32),
#   array(0.00722431, dtype=float32),
#   array(0.00721061, dtype=float32),
#   array(0.00719698, dtype=float32),
#   array(0.00718338, dtype=float32),
#   array(0.00716985, dtype=float32),
#   array(0.00715636, dtype=float32),
#   array(0.00714292, dtype=float32),
#   array(0.00712954, dtype=float32),
#   array(0.00711621, dtype=float32),
#   array(0.00710293, dtype=float32),
#   array(0.00708969, dtype=float32),
#   array(0.00707653, dtype=float32),
#   array(0.0070634, dtype=float32),
#   array(0.00705033, dtype=float32),
#   array(0.00703731, dtype=float32),
#   array(0.00702432, dtype=float32),
#   array(0.00701142, dtype=float32),
#   array(0.00699853, dtype=float32),
#   array(0.00698572, dtype=float32),
#   array(0.00697293, dtype=float32),
#   array(0.00696021, dtype=float32),
#   array(0.00694752, dtype=float32),
#   array(0.00693488, dtype=float32),
#   array(0.00692229, dtype=float32),
#   array(0.00690974, dtype=float32),
#   array(0.00689725, dtype=float32),
#   array(0.00688481, dtype=float32),
#   array(0.00687241, dtype=float32),
#   array(0.00686006, dtype=float32),
#   array(0.00684774, dtype=float32),
#   array(0.00683547, dtype=float32),
#   array(0.00682324, dtype=float32),
#   array(0.00681106, dtype=float32),
#   array(0.00679893, dtype=float32),
#   array(0.00678685, dtype=float32),
#   array(0.00677481, dtype=float32),
#   array(0.00676282, dtype=float32),
#   array(0.00675087, dtype=float32),
#   array(0.00673896, dtype=float32),
#   array(0.0067271, dtype=float32),
#   array(0.00671527, dtype=float32),
#   array(0.00670348, dtype=float32),
#   array(0.00669175, dtype=float32),
#   array(0.00668006, dtype=float32),
#   array(0.00666841, dtype=float32),
#   array(0.00665679, dtype=float32),
#   array(0.00664522, dtype=float32),
#   array(0.0066337, dtype=float32),
#   array(0.00662222, dtype=float32),
#   array(0.00661078, dtype=float32),
#   array(0.00659938, dtype=float32),
#   array(0.006588, dtype=float32),
#   array(0.00657668, dtype=float32),
#   array(0.0065654, dtype=float32),
#   array(0.00655416, dtype=float32),
#   array(0.00654296, dtype=float32),
#   array(0.00653182, dtype=float32),
#   array(0.00652069, dtype=float32),
#   array(0.00650961, dtype=float32),
#   array(0.00649857, dtype=float32),
#   array(0.00648757, dtype=float32),
#   array(0.00647659, dtype=float32),
#   array(0.00646567, dtype=float32),
#   array(0.00645477, dtype=float32),
#   array(0.00644391, dtype=float32),
#   array(0.00643309, dtype=float32),
#   array(0.00642234, dtype=float32),
#   array(0.0064116, dtype=float32),
#   array(0.0064009, dtype=float32),
#   array(0.00639025, dtype=float32),
#   array(0.0063796, dtype=float32),
#   array(0.00636902, dtype=float32),
#   array(0.00635844, dtype=float32),
#   array(0.0063479, dtype=float32),
#   array(0.00633742, dtype=float32),
#   array(0.00632695, dtype=float32),
#   array(0.00631656, dtype=float32),
#   array(0.00630617, dtype=float32),
#   array(0.00629583, dtype=float32),
#   array(0.00628551, dtype=float32),
#   array(0.00627523, dtype=float32),
#   array(0.006265, dtype=float32),
#   array(0.0062548, dtype=float32),
#   array(0.00624462, dtype=float32),
#   array(0.00623449, dtype=float32),
#   array(0.0062244, dtype=float32),
#   array(0.00621433, dtype=float32),
#   array(0.0062043, dtype=float32),
#   array(0.0061943, dtype=float32),
#   array(0.00618433, dtype=float32),
#   array(0.0061744, dtype=float32),
#   array(0.0061645, dtype=float32),
#   array(0.00615463, dtype=float32),
#   array(0.00614479, dtype=float32),
#   array(0.006135, dtype=float32),
#   array(0.00612522, dtype=float32),
#   array(0.00611549, dtype=float32),
#   array(0.00610579, dtype=float32),
#   array(0.00609611, dtype=float32),
#   array(0.00608649, dtype=float32),
#   array(0.00607688, dtype=float32),
#   array(0.00606731, dtype=float32),
#   array(0.00605777, dtype=float32),
#   array(0.00604825, dtype=float32),
#   array(0.00603877, dtype=float32),
#   array(0.00602931, dtype=float32),
#   array(0.00601989, dtype=float32),
#   array(0.00601048, dtype=float32),
#   array(0.00600113, dtype=float32),
#   array(0.00599179, dtype=float32),
#   array(0.00598249, dtype=float32),
#   array(0.00597321, dtype=float32),
#   array(0.00596395, dtype=float32),
#   array(0.00595474, dtype=float32),
#   array(0.00594555, dtype=float32),
#   array(0.00593639, dtype=float32),
#   array(0.00592725, dtype=float32),
#   array(0.00591815, dtype=float32),
#   array(0.00590908, dtype=float32),
#   array(0.00590004, dtype=float32),
#   array(0.00589103, dtype=float32),
#   array(0.00588205, dtype=float32),
#   array(0.00587309, dtype=float32),
#   array(0.00586417, dtype=float32),
#   array(0.00585527, dtype=float32),
#   array(0.00584641, dtype=float32),
#   array(0.00583756, dtype=float32),
#   array(0.00582873, dtype=float32),
#   array(0.00581995, dtype=float32),
#   array(0.00581119, dtype=float32),
#   array(0.00580246, dtype=float32),
#   array(0.00579376, dtype=float32),
#   array(0.00578508, dtype=float32),
#   array(0.00577643, dtype=float32),
#   array(0.0057678, dtype=float32),
#   array(0.00575919, dtype=float32),
#   array(0.00575061, dtype=float32),
#   array(0.00574206, dtype=float32),
# ...
#   np.float32(0.00020938029),
#   np.float32(0.00020891371),
#   np.float32(0.0002084492),
#   np.float32(0.00020798676),
#   np.float32(0.00020752635),
#   np.float32(0.00020706799),
#   np.float32(0.00020661164),
#   np.float32(0.0002061573),
#   np.float32(0.00020570494),
#   np.float32(0.00020525458),
#   np.float32(0.00020480619),
#   np.float32(0.00020435973),
#   np.float32(0.00020391523),
#   np.float32(0.00020347265),
#   np.float32(0.000203032),
#   np.float32(0.00020259325),
#   np.float32(0.0002021564),
#   np.float32(0.00020172141),
#   np.float32(0.0002012883),
#   np.float32(0.00020085704),
#   np.float32(0.00020042763),
#   np.float32(0.00020000005),
#   np.float32(0.0001995743),
#   np.float32(0.00019915035),
#   np.float32(0.0001987282),
#   np.float32(0.00019830783),
#   np.float32(0.00019788924),
#   np.float32(0.00019747241),
#   np.float32(0.00019705734),
#   np.float32(0.00019664399),
#   np.float32(0.0001962324),
#   np.float32(0.0001958225),
#   np.float32(0.00019541432),
#   np.float32(0.00019500786),
#   np.float32(0.00019460305),
#   np.float32(0.00019419995),
#   np.float32(0.0001937985),
#   np.float32(0.00019339871),
#   np.float32(0.00019300057),
#   np.float32(0.00019260406),
#   np.float32(0.00019220918),
#   np.float32(0.0001918159),
#   np.float32(0.00019142425),
#   np.float32(0.00019103418),
#   np.float32(0.00019064569),
#   np.float32(0.00019025881),
#   np.float32(0.00018987348),
#   np.float32(0.00018948968),
#   np.float32(0.00018910746),
#   np.float32(0.00018872677),
#   np.float32(0.0001883476),
#   np.float32(0.00018796997),
#   np.float32(0.00018759385),
#   np.float32(0.00018721922),
#   np.float32(0.0001868461),
#   np.float32(0.00018647444),
#   np.float32(0.00018610427),
#   np.float32(0.00018573555),
#   np.float32(0.0001853683),
#   np.float32(0.00018500251),
#   np.float32(0.00018463816),
#   np.float32(0.00018427524),
#   np.float32(0.00018391373),
#   np.float32(0.00018355364),
#   np.float32(0.00018319496),
#   np.float32(0.00018283768),
#   np.float32(0.0001824818),
#   np.float32(0.00018212729),
#   np.float32(0.00018177416),
#   np.float32(0.0001814224),
#   np.float32(0.00018107198),
